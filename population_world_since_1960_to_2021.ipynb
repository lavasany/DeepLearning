# %% [markdown]
# <a href="https://colab.research.google.com/github/lavasany/DeepLearning/blob/main/population_world_since_1960_to_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split,cross_val_score,cross_val_predict
#from sklearn.linear_model import LinearRegression
#import statsmodels.api as sm
#from sklearn.metrics import mean_squared_error,r2_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn import preprocessing
from sklearn.naive_bayes import GaussianNB , MultinomialNB
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv ("/data_population_world.csv")

# %%
#برای اینکه کل متغیرها را در ستون ها ببینیم از دستور زیر استفاده می کنیم
from IPython.core.display import HTML
display(HTML(df.to_html() ) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country Name</th>
#       <th>Country Code</th>
#       <th>Indicator Name</th>
#       <th>Indicator Code</th>
#       <th>1960</th>
#       <th>1961</th>
#       <th>1962</th>
#       <th>1963</th>
#       <th>1964</th>
#       <th>1965</th>
#       <th>1966</th>
#       <th>1967</th>
#       <th>1968</th>
#       <th>1969</th>
#       <th>1970</th>
#       <th>1971</th>
#       <th>1972</th>
#       <th>1973</th>
#       <th>1974</th>
#       <th>1975</th>
#       <th>1976</th>
#       <th>1977</th>
#       <th>1978</th>
#       <th>1979</th>
#       <th>1980</th>
#       <th>1981</th>
#       <th>1982</th>
#       <th>1983</th>
#       <th>1984</th>
#       <th>1985</th>
#       <th>1986</th>
#       <th>1987</th>
#       <th>1988</th>
#       <th>1989</th>
#       <th>1990</th>
#       <th>1991</th>
#       <th>1992</th>
#       <th>1993</th>
# ...

# %%
df = df.drop([110,196], axis = 0)
df
# Out:
#         Country Name Country Code    Indicator Name Indicator Code  \
# 0              Aruba          ABW  Población, total    SP.POP.TOTL
# 1                NaN          AFE  Población, total    SP.POP.TOTL
# 2         Afganistán          AFG  Población, total    SP.POP.TOTL
# 3                NaN          AFW  Población, total    SP.POP.TOTL
# 4             Angola          AGO  Población, total    SP.POP.TOTL
# ..               ...          ...               ...            ...
# 261           Kosovo          XKX  Población, total    SP.POP.TOTL
# 262  Yemen, Rep. del          YEM  Población, total    SP.POP.TOTL
# 263        Sudáfrica          ZAF  Población, total    SP.POP.TOTL
# 264           Zambia          ZMB  Población, total    SP.POP.TOTL
# 265         Zimbabwe          ZWE  Población, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# ...

# %%
df
# Out:
#         Country Name Country Code    Indicator Name Indicator Code  \
# 0              Aruba          ABW  Población, total    SP.POP.TOTL
# 1                NaN          AFE  Población, total    SP.POP.TOTL
# 2         Afganistán          AFG  Población, total    SP.POP.TOTL
# 3                NaN          AFW  Población, total    SP.POP.TOTL
# 4             Angola          AGO  Población, total    SP.POP.TOTL
# ..               ...          ...               ...            ...
# 261           Kosovo          XKX  Población, total    SP.POP.TOTL
# 262  Yemen, Rep. del          YEM  Población, total    SP.POP.TOTL
# 263        Sudáfrica          ZAF  Población, total    SP.POP.TOTL
# 264           Zambia          ZMB  Población, total    SP.POP.TOTL
# 265         Zimbabwe          ZWE  Población, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
from pandas_profiling import profile_report
df.profile_report()

# %%
df.isna().sum()
# Out:
# Country Name        2
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                0
#                  ...
# 2018                0
# 2019                0
# 2020                0
# 2021                0
# Unnamed: 66       264
# Length: 67, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()
for c in df.columns:
    if df[c].dtypes=='float64':
        df[c] = LE.fit_transform(df[c])

# %%
df.isna().sum()
# Out:
# Country Name      2
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# Unnamed: 66       0
# Length: 67, dtype: int64

# %%
df['Country Name']= df['Country Name'].fillna(0)

# %%
df

# %%
df.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# Unnamed: 66       0
# Length: 67, dtype: int64

# %%
import plotly.express as px
fig = px.scatter(df.dropna(subset=['Country Name']), x='Country Name', y=['1960', '2021'])
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
bam.plot(df)

# %%
df_dub = df.drop_duplicates()

print(df.shape, df_dub.shape)
# Out:
# (264, 67) (264, 67)

# %%
from pandasgui import show
gui=show(df)

# %% [markdown]
# # So far, we have identified null and missing data, and the data set has been cleaned, and according to the type of data, we do not have outliers.
