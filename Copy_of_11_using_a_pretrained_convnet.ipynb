# %% [markdown]
# <a href="https://colab.research.google.com/github/lavasany/DeepLearning/blob/main/Copy_of_11_using_a_pretrained_convnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">به نام خدا</div></center>
# <h1><center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">استفاده از شبکه‌های از قبل آموزش داده شده
# </h1>

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# خطای رایج:
# <br>
#
# [cannot download vgg16_weights](https://github.com/fchollet/deep-learning-models/issues/33)
# <br>
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# راهکار؟
# <br>
# </div>
#
# You can download it manually from here: https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# and paste it on
# ~/.keras/models

# %%
import os
os.path.expanduser('~/.keras/models')
# Out:
# 'C:\\Users\\alire/.keras/models'

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

# %%
model = VGG16(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 5s 0us/step
# 553476096/553467096 [==============================] - 5s 0us/step

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !wget https://media.npr.org/assets/img/2021/07/09/gettyimages-814391901_wide-3f1f786bbc027eec2039244d1fbb6807d5a2d8dd-s800-c85.webp
# Out:
# --2022-02-25 17:44:05--  https://media.npr.org/assets/img/2021/07/09/gettyimages-814391901_wide-3f1f786bbc027eec2039244d1fbb6807d5a2d8dd-s800-c85.webp
# Resolving media.npr.org (media.npr.org)... 23.219.33.139, 2600:1417:76:581::1155, 2600:1417:76:587::1155
# Connecting to media.npr.org (media.npr.org)|23.219.33.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/webp]
# Saving to: ‘gettyimages-814391901_wide-3f1f786bbc027eec2039244d1fbb6807d5a2d8dd-s800-c85.webp’
#
# gettyimages-8143919     [   <=>              ]  45.58K  59.4KB/s    in 0.8s
#
# 2022-02-25 17:44:09 (59.4 KB/s) - ‘gettyimages-814391901_wide-3f1f786bbc027eec2039244d1fbb6807d5a2d8dd-s800-c85.webp’ saved [46670]

# %%
img_path = 'panda.webp'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# 49152/35363 [=========================================] - 0s 0us/step
# Predicted: [('n02510455', 'giant_panda', 0.9991093), ('n02509815', 'lesser_panda', 0.0003073106), ('n02447366', 'badger', 0.00010124745)]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F0020E47990>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
preds.shape
# Out:
# (1, 1000)

# %%
np.sum(preds)
# Out:
# 0.9999999

# %%
np.max(preds)
# Out:
# 0.9991093

# %%
np.argmax(preds)
# Out:
# 388

# %%
 decode_predictions(preds)
# Out:
# [[('n02510455', 'giant_panda', 0.9991093),
#   ('n02509815', 'lesser_panda', 0.0003073106),
#   ('n02447366', 'badger', 0.00010124745),
#   ('n04254680', 'soccer_ball', 0.0001006283),
#   ('n02133161', 'American_black_bear', 6.998187e-05)]]

# %%
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02510455', 'giant_panda', 0.9991093), ('n02509815', 'lesser_panda', 0.0003073106), ('n02447366', 'badger', 0.00010124745)]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> دوره مقدماتی یادگیری عمیق<br>علیرضا اخوان پور<br>پنج شنبه، ۲۵ بهمن ۱۳۹۷<br>
# </div>
# <a href="http://class.vision">Class.Vision</a> - <a href="http://AkhavanPour.ir">AkhavanPour.ir</a> - <a href="https://github.com/Alireza-Akhavan/">GitHub</a>
#
# </div>
